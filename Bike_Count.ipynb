# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data=pd.read_csv("day.csv")
data.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
data.index=data.instant
data.drop(['instant'],axis=1,inplace=True)
data.head()
# Out:
#              dteday  season  yr  mnth  holiday  weekday  workingday  \
# instant
# 1        2011-01-01       1   0     1        0        6           0
# 2        2011-01-02       1   0     1        0        0           0
# 3        2011-01-03       1   0     1        0        1           1
# 4        2011-01-04       1   0     1        0        2           1
# 5        2011-01-05       1   0     1        0        3           1
#
#          weathersit      temp     atemp       hum  windspeed  casual  \
# instant
# 1                 2  0.344167  0.363625  0.805833   0.160446     331
# 2                 2  0.363478  0.353739  0.696087   0.248539     131
# 3                 1  0.196364  0.189405  0.437273   0.248309     120
# 4                 1  0.200000  0.212122  0.590435   0.160296     108
# 5                 1  0.226957  0.229270  0.436957   0.186900      82
#
#          registered   cnt
# instant
# 1               654   985
# 2               670   801
# 3              1229  1349
# ...

# %%
data.shape
# Out:
# (731, 15)

# %%
df=data[['season','mnth','holiday','weekday','workingday','weathersit','temp','atemp','hum','windspeed','cnt']]

# %% [markdown]
# # Correlation

# %%
#here dependent variable is cnt
dfcor=df.corr()
dfcor.cnt
# Out:
# season        0.406100
# mnth          0.279977
# holiday      -0.068348
# weekday       0.067443
# workingday    0.061156
# weathersit   -0.297391
# temp          0.627494
# atemp         0.631066
# hum          -0.100659
# windspeed    -0.234545
# cnt           1.000000
# Name: cnt, dtype: float64

# %%
dfcor.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_00e7d706_27d5_11ea_91c5_ccaf78a773f1row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_00e7d706_27d5_11ea_91c5_ccaf78a773f1row0_col1 {
#             background-color:  #e16751;
#             color:  #000000;
#         }    #T_00e7d706_27d5_11ea_91c5_ccaf78a773f1row0_col2 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_00e7d706_27d5_11ea_91c5_ccaf78a773f1row0_col3 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_00e7d706_27d5_11ea_91c5_ccaf78a773f1row0_col4 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_00e7d706_27d5_11ea_91c5_ccaf78a773f1row0_col5 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_00e7d706_27d5_11ea_91c5_ccaf78a773f1row0_col6 {
#             background-color:  #c7d7f0;
#             color:  #000000;
# ...

# %%
#Here highly correlated variables are temp ,atemp 

X=df[['temp','atemp']]
y=df[['cnt']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test =train_test_split(X,y, test_size=0.1,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,y_train)
regressor
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
import statsmodels.api as sm
x1=sm.add_constant(X)
sm.OLS(y,x1).fit().summary()
# Out:
# C:\Users\reshw\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.398
# Model:                            OLS   Adj. R-squared:                  0.397
# Method:                 Least Squares   F-statistic:                     241.1
# Date:                Thu, 26 Dec 2019   Prob (F-statistic):           4.62e-81
# Time:                        17:55:18   Log-Likelihood:                -6383.9
# No. Observations:                 731   AIC:                         1.277e+04
# Df Residuals:                     728   BIC:                         1.279e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...

# %%
#Model 2
X=data[['season','mnth','holiday','weekday','workingday','weathersit','temp','atemp','hum','windspeed']]

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test =train_test_split(X,y, test_size=0.1,random_state=1)

from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#Anova table with all indipendent variables
import statsmodels.api as sm
x1=sm.add_constant(X)
sm.OLS(y,x1).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.528
# Model:                            OLS   Adj. R-squared:                  0.521
# Method:                 Least Squares   F-statistic:                     80.53
# Date:                Thu, 26 Dec 2019   Prob (F-statistic):          2.43e-110
# Time:                        18:50:54   Log-Likelihood:                -6295.3
# No. Observations:                 731   AIC:                         1.261e+04
# Df Residuals:                     720   BIC:                         1.266e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3033.3075    360.945      8.404      0.000    2324.676    3741.939
# ...

# %% [markdown]
# Here Adjuste R2 square value is imprroved.This is best fit model

# %%
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# [3110.94642395]
# [[  474.94276178   -23.37535812  -429.19424475    68.10822243
#     100.44314968  -504.56705344  2723.91686913  3258.07561157
#   -2380.17987427 -3027.643086  ]]
